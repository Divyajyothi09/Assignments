# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Name_of_company = ['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers','Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways','Warner-Lambert']

# %%
Measure_X = [24.23, 25.53,25.41,24.41,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35]

# %%
df = pd.DataFrame(Measure_X,Name_of_company)

# %%
df
# Out:
#                       0
# Allied Signal     24.23
# Bankers Trust     25.53
# General Mills     25.41
# ITT Industries    24.41
# J.P.Morgan & Co.  29.62
# Lehman Brothers   28.25
# Marriott          25.81
# MCI               24.39
# Merrill Lynch     40.26
# Microsoft         32.95
# Morgan Stanley    91.36
# Sun Microsystems  25.99
# Travelers         39.42
# US Airways        26.71
# Warner-Lambert    35.00

# %%
plt.pie(Measure_X,labels=Name_of_company,autopct='%1.0f%%')
plt.show()

# %%
df.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
# Box plot to find outliers
plt.boxplot(df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x277d5b14700>,
#   <matplotlib.lines.Line2D at 0x277d5b149d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x277d5b14ca0>,
#   <matplotlib.lines.Line2D at 0x277d5b14f70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x277d5b14430>],
#  'medians': [<matplotlib.lines.Line2D at 0x277d5ae2280>],
#  'fliers': [<matplotlib.lines.Line2D at 0x277d5ae2550>],
#  'means': []}

# %%
# Mean(μ)
df.mean()
# Out:
# 0    33.289333
# dtype: float64

# %%
# Vairance(	σ^2)
df.var()
# Out:
# 0    286.799264
# dtype: float64

# %%
# Standard Deviation(σ)
df.std()
# Out:
# 0    16.935149
# dtype: float64
